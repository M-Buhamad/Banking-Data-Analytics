# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('cards_data.csv',dtype={'has_chip':'category','card_brand':'category','card_type':'category','card_on_dark_web': 'category'})
df.head(6)
# Out:
#      id  client_id  card_brand        card_type       card_number  expires  \
# 0  4524        825        Visa            Debit  4344676511950444  12/2022
# 1  2731        825        Visa            Debit  4956965974959986  12/2020
# 2  3701        825        Visa            Debit  4582313478255491  02/2024
# 3    42        825        Visa           Credit  4879494103069057  08/2024
# 4  4659        825  Mastercard  Debit (Prepaid)  5722874738736011  03/2009
# 5  4537       1746        Visa           Credit  4404898874682993  09/2003
#
#    cvv has_chip  num_cards_issued credit_limit acct_open_date  \
# 0  623      YES                 2       $24295        09/2002
# 1  393      YES                 2       $21968        04/2014
# 2  719      YES                 2       $46414        07/2003
# 3  693       NO                 1       $12400        01/2003
# 4   75      YES                 1          $28        09/2008
# 5  736      YES                 1       $27500        09/2003
#
# ...

# %%
df['card_brand'].values.categories
# Out:
# Index(['Amex', 'Discover', 'Mastercard', 'Visa'], dtype='object')

# %%
df['card_type'].values.categories
# Out:
# Index(['Credit', 'Debit', 'Debit (Prepaid)'], dtype='object')

# %%
df['has_chip'].values.categories
# Out:
# Index(['NO', 'YES'], dtype='object')

# %%
df['card_on_dark_web'].values.categories
# Out:
# Index(['No'], dtype='object')

# %%
df['acct_open_date'] = pd.to_datetime(df['acct_open_date'], format='%m/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6146 entries, 0 to 6145
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     6146 non-null   int64
#  1   client_id              6146 non-null   int64
#  2   card_brand             6146 non-null   category
#  3   card_type              6146 non-null   category
#  4   card_number            6146 non-null   int64
#  5   expires                6146 non-null   object
#  6   cvv                    6146 non-null   int64
#  7   has_chip               6146 non-null   category
#  8   num_cards_issued       6146 non-null   int64
#  9   credit_limit           6146 non-null   object
#  10  acct_open_date         6146 non-null   datetime64[ns]
#  11  year_pin_last_changed  6146 non-null   int64
#  12  card_on_dark_web       6146 non-null   category
# dtypes: category(4), datetime64[ns](1), int64(6), object(2)
# ...

# %%
df['expires'] = pd.to_datetime(df['expires'], format='%m/%Y')

# %%
df['credit_limit'] = df['credit_limit'].str.replace('$', '', regex=False).astype(int)

# %%
# Now check all the data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6146 entries, 0 to 6145
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     6146 non-null   int64
#  1   client_id              6146 non-null   int64
#  2   card_brand             6146 non-null   category
#  3   card_type              6146 non-null   category
#  4   card_number            6146 non-null   int64
#  5   expires                6146 non-null   datetime64[ns]
#  6   cvv                    6146 non-null   int64
#  7   has_chip               6146 non-null   category
#  8   num_cards_issued       6146 non-null   int64
#  9   credit_limit           6146 non-null   int64
#  10  acct_open_date         6146 non-null   datetime64[ns]
#  11  year_pin_last_changed  6146 non-null   int64
#  12  card_on_dark_web       6146 non-null   category
# dtypes: category(4), datetime64[ns](2), int64(7)
# memory usage: 456.7 KB

# %%
df.loc[df.isna().any(axis=1)] # no missing values
# Out:
# Empty DataFrame
# Columns: [id, client_id, card_brand, card_type, card_number, expires, cvv, has_chip, num_cards_issued, credit_limit, acct_open_date, year_pin_last_changed, card_on_dark_web]
# Index: []

# %%
df.loc[df['cvv'] <100]
# Out:
#         id  client_id  card_brand        card_type       card_number  \
# 4     4659        825  Mastercard  Debit (Prepaid)  5722874738736011
# 7     3687       1746  Mastercard            Debit  5627220683410948
# 17    5621        708        Visa            Debit  4032240655674503
# 20      27         68        Visa           Credit  4099623033306950
# 37     138       1094        Visa            Debit  4556928160477229
# ...    ...        ...         ...              ...               ...
# 6071   171          7  Mastercard            Debit  5673440794177682
# 6085  2546       1805  Mastercard           Credit  5541745788882180
# 6098  3752       1528        Visa           Credit  4784666596890935
# 6127  3488        391  Mastercard            Debit  5021628982108623
# 6132  1765        588  Mastercard            Debit  5800888888822204
#
#         expires  cvv has_chip  num_cards_issued  credit_limit acct_open_date  \
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, client_id, card_brand, card_type, card_number, expires, cvv, has_chip, num_cards_issued, credit_limit, acct_open_date, year_pin_last_changed, card_on_dark_web]
# Index: []

# %%
df.to_csv("cards_data_cleaned.csv", index=False)
