# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('transactions_data.csv',dtype={'use_chip':'category','merchant_city':'category','merchant_state':'category','errors': 'category'})

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13305915 entries, 0 to 13305914
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   id              int64
#  1   date            datetime64[ns]
#  2   client_id       int64
#  3   card_id         int64
#  4   amount          object
#  5   use_chip        category
#  6   merchant_id     int64
#  7   merchant_city   category
#  8   merchant_state  category
#  9   zip             float64
#  10  mcc             int64
#  11  errors          category
# dtypes: category(4), datetime64[ns](1), float64(1), int64(5), object(1)
# memory usage: 888.6+ MB

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, date, client_id, card_id, amount, use_chip, merchant_id, merchant_city, merchant_state, zip, mcc, errors]
# Index: []

# %%
df.head()
# Out:
#         id                date  client_id  card_id   amount  \
# 0  7475327 2010-01-01 00:01:00       1556     2972  $-77.00
# 1  7475328 2010-01-01 00:02:00        561     4575   $14.57
# 2  7475329 2010-01-01 00:02:00       1129      102   $80.00
# 3  7475331 2010-01-01 00:05:00        430     2860  $200.00
# 4  7475332 2010-01-01 00:06:00        848     3915   $46.41
#
#             use_chip  merchant_id merchant_city merchant_state      zip   mcc  \
# 0  Swipe Transaction        59935        Beulah             ND  58523.0  5499
# 1  Swipe Transaction        67570    Bettendorf             IA  52722.0  5311
# 2  Swipe Transaction        27092         Vista             CA  92084.0  4829
# 3  Swipe Transaction        27092   Crown Point             IN  46307.0  4829
# 4  Swipe Transaction        13051       Harwood             MD  20776.0  5813
#
#   errors
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
df['amount'] = df['amount'].str.replace('$', '', regex=False).astype(float)

# %%
df.loc[df['errors'].notna()]
# Out:
#                 id                date  client_id  card_id  amount  \
# 166        7475516 2010-01-01 04:56:00        464     3233  104.10
# 248        7475611 2010-01-01 06:10:00       1797     1127   28.84
# 275        7475643 2010-01-01 06:19:00       1797     1127   38.58
# 401        7475792 2010-01-01 07:02:00       1424     4710  -72.00
# 483        7475881 2010-01-01 07:22:00        843      184   37.54
# ...            ...                 ...        ...      ...     ...
# 13305422  23761252 2019-10-31 19:13:00       1902     3056   99.28
# 13305606  23761496 2019-10-31 20:48:00       1985     4085   10.74
# 13305757  23761675 2019-10-31 21:57:00         87     3607   20.00
# 13305803  23761735 2019-10-31 22:23:00       1851     3164  166.38
# 13305894  23761849 2019-10-31 23:39:00        348     3073   61.67
#
#                     use_chip  merchant_id merchant_city merchant_state  \
# 166        Swipe Transaction        32175       Orlando             FL
# ...

# %%
df.loc[df.drop(columns=['errors','merchant_state']).isna().any(axis=1) & (df['merchant_city'] != 'ONLINE')]
# Out:
#                 id                date  client_id  card_id  amount  \
# 581        7476010 2010-01-01 07:53:00       1579     3830    6.51
# 1026       7476549 2010-01-01 10:03:00        363     5555    8.16
# 1148       7476704 2010-01-01 10:37:00        363     5555   11.66
# 1706       7477375 2010-01-01 12:50:00       1266     2478    9.77
# 1836       7477534 2010-01-01 13:19:00       1266     2478   11.32
# ...            ...                 ...        ...      ...     ...
# 13304162  23759669 2019-10-31 13:16:00        905       53   18.97
# 13304376  23759927 2019-10-31 14:03:00        905     5053  171.95
# 13304475  23760060 2019-10-31 14:28:00        905     5053 -377.00
# 13305061  23760796 2019-10-31 16:45:00        738     5774  317.42
# 13305140  23760892 2019-10-31 16:58:00        738     5774 -494.00
#
#                    use_chip  merchant_id    merchant_city  merchant_state  \
# 581       Swipe Transaction        22204  Puerto Vallarta          Mexico
# ...

# %%
df['merchant_city'].values.categories
# Out:
# Index(['Abbeville', 'Aberdeen', 'Abilene', 'Abingdon', 'Abita Springs',
#        'Absecon', 'Abu Dhabi', 'Accokeek', 'Acworth', 'Adams',
#        ...
#        'Virginia City', 'Weatogue', 'Chester Heights', 'Dalton City',
#        'East Point', 'Eastville', 'El Rito', 'Maidens', 'King Ferry',
#        'Shawboro'],
#       dtype='object', length=12492)

# %%
df['merchant_state'].values.categories
# Out:
# Index(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'Canada', 'China',
#        'Costa Rica',
#        ...
#        'Albania', 'Guinea', 'Papua New Guinea', 'East Timor (Timor-Leste)',
#        'Sudan', 'Venezuela', 'Trinidad and Tobago', 'Republic of the Congo',
#        'Azerbaijan', 'Guyana'],
#       dtype='object', length=199)

# %%
df['use_chip'].values.categories
# Out:
# Index(['Online Transaction', 'Swipe Transaction', 'Chip Transaction'], dtype='object')

# %%
df['errors'].values.categories
# Out:
# Index(['Bad CVV', 'Bad Card Number', 'Bad Card Number,Bad Expiration',
#        'Bad Card Number,Insufficient Balance', 'Bad Expiration',
#        'Bad Expiration,Technical Glitch', 'Bad PIN',
#        'Bad PIN,Insufficient Balance', 'Bad PIN,Technical Glitch',
#        'Bad Zipcode', 'Insufficient Balance',
#        'Insufficient Balance,Technical Glitch', 'Technical Glitch',
#        'Bad Card Number,Bad CVV', 'Bad Expiration,Insufficient Balance',
#        'Bad CVV,Technical Glitch', 'Bad Expiration,Bad CVV',
#        'Bad CVV,Insufficient Balance', 'Bad Card Number,Technical Glitch',
#        'Bad Zipcode,Insufficient Balance',
#        'Bad Card Number,Bad Expiration,Insufficient Balance',
#        'Bad Zipcode,Technical Glitch'],
#       dtype='object')

# %%
df.head(10)
# Out:
#         id                date  client_id  card_id  amount  \
# 0  7475327 2010-01-01 00:01:00       1556     2972  -77.00
# 1  7475328 2010-01-01 00:02:00        561     4575   14.57
# 2  7475329 2010-01-01 00:02:00       1129      102   80.00
# 3  7475331 2010-01-01 00:05:00        430     2860  200.00
# 4  7475332 2010-01-01 00:06:00        848     3915   46.41
# 5  7475333 2010-01-01 00:07:00       1807      165    4.81
# 6  7475334 2010-01-01 00:09:00       1556     2972   77.00
# 7  7475335 2010-01-01 00:14:00       1684     2140   26.46
# 8  7475336 2010-01-01 00:21:00        335     5131  261.58
# 9  7475337 2010-01-01 00:21:00        351     1112   10.74
#
#              use_chip  merchant_id merchant_city merchant_state      zip  \
# 0   Swipe Transaction        59935        Beulah             ND  58523.0
# 1   Swipe Transaction        67570    Bettendorf             IA  52722.0
# 2   Swipe Transaction        27092         Vista             CA  92084.0
# ...

# %%
df.to_csv("transactions_data_cleaned.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.to_csv("transactions_data_cleaned.csv", index=False)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
